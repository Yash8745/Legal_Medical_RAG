# %% [markdown]
# # How to summarize large boddies of text

# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from rich import print
import os

load_dotenv()

GEMINI_API_KEY=os.getenv("GEMINI_API_KEY")
print(GEMINI_API_KEY)
# Out:
# AIzaSyCdNUTYXOt7x7En2CV1jaOka7ZMcZqr2eA

# %%
from google import genai

client = genai.Client(api_key=GEMINI_API_KEY)
response = client.models.generate_content(
    model="gemini-2.0-pro-exp-02-05", contents="Explain how AI works"
)
print(response)
# Out:
# GenerateContentResponse(
#     candidates=[
#         Candidate(
#             content=Content(
#                 parts=[
#                     Part(
#                         video_metadata=None,
#                         thought=None,
#                         code_execution_result=None,
#                         executable_code=None,
#                         file_data=None,
#                         function_call=None,
#                         function_response=None,
#                         inline_data=None,
#                         text='Let\'s break down how AI works, keeping it as clear and concise as possible.  We\'ll
# cover the core concepts and then touch on different types of AI.\n\n**1.  The Fundamental Idea: Mimicking Human
# Intelligence**\n\nAt its heart, AI is about creating computer systems that can perform tasks that typically require
# *human intelligence*.  This includes things like:\n\n*   **Learning:**  Adapting to new information and improving
# performance over time.\n*   **Reasoning:**  Drawing conclusions and making decisions based on information.\n*
# **Problem-solving:**  Finding solutions to challenges.\n*   **Perception:**  Understanding and interpreting sensory
# input (like images, sounds, or text).\n*   **Language understanding:**  Comprehending and generating human
# language.\n\n**2. Key Techniques: How AI "Thinks" (Simplified)**\n\nAI achieves these abilities primarily through
# the following techniques:\n\n*   **Machine Learning (ML):**  This is the most prominent and arguably most important
# aspect of modern AI.  ML algorithms allow computers to "learn" from data *without* being explicitly programmed for
# every scenario.  Instead of giving the computer rigid rules, you feed it examples, and it figures out the patterns
# itself.  Think of it like this:\n\n    *   **Traditional Programming:** You tell the computer *exactly* what to do:
# "If the input is \'red,\' output \'stop.\'"\n    *   **Machine Learning:** You show the computer many examples:
# "Red = stop," "Green = go," "Yellow = caution."  The computer learns the relationship between the input and the
# output.\n\n    There are several types of machine learning:\n    *   **Supervised Learning:**  You provide the
# algorithm with labeled data (input and the *correct* output).  The AI learns to map inputs to outputs.  Examples:
# spam filtering, image classification.\n    *   **Unsupervised Learning:**  You provide the algorithm with unlabeled
# data, and it finds patterns and structures on its own.  Examples: customer segmentation, anomaly detection.\n    *
# **Reinforcement Learning:**  The AI learns through trial and error.  It receives rewards for correct actions and
# penalties for incorrect ones, gradually learning the optimal strategy.  Examples: game playing (like Go or chess),
# robotics.\n\n*   **Deep Learning (DL):** A specialized and powerful subset of machine learning.  Deep learning uses
# *artificial neural networks* with many layers (hence "deep"). These networks are inspired by the structure of the
# human brain.\n\n    *   **Neural Networks:**  These are interconnected nodes (like neurons) organized in layers.
# Each connection has a "weight" that determines the strength of the signal.  The network learns by adjusting these
# weights based on the data it\'s exposed to.\n    *   **Layers:**  Input data passes through multiple layers.  Each
# layer extracts increasingly complex features.  For example, in image recognition:\n        *   Layer 1 might detect
# edges and corners.\n        *   Layer 2 might combine edges to form shapes.\n        *   Layer 3 might identify
# objects based on shapes.\n        *   ...and so on, until the final layer outputs a prediction (e.g., "This is a
# cat").\n\n    Deep learning excels at tasks involving large amounts of complex data, such as image recognition,
# natural language processing, and speech recognition.\n\n*   **Natural Language Processing (NLP):**  This focuses on
# enabling computers to understand, interpret, and generate human language.  NLP uses various techniques,
# including:\n\n    *   **Tokenization:** Breaking down text into individual words or phrases.\n    *
# **Part-of-speech tagging:** Identifying the grammatical role of each word (noun, verb, adjective, etc.).\n    *
# **Sentiment analysis:** Determining the emotional tone of a piece of text (positive, negative, neutral).\n    *
# **Machine translation:**  Converting text from one language to another.\n    *   **Text generation:**  Creating new
# text, like writing summaries or answering questions.\n\n*    **Computer Vision:** Computer vision is a field of AI
# that enables computers and systems to derive meaningful information from digital images, videos and other visual
# inputs — and take actions or make recommendations based on that information.\n\n*   **Rule-Based Systems (Less
# common in modern AI):**  These systems rely on a set of pre-defined rules created by human experts.  They are
# effective for tasks with clear, logical rules, but they are not as flexible or adaptable as machine learning
# approaches.\n\n**3.  A Simple Example: Spam Filtering**\n\nLet\'s illustrate with a spam filter:\n\n1.  **Data:**
# You provide the AI with a large dataset of emails, each labeled as either "spam" or "not spam."\n2.  **Feature
# Extraction:**  The AI analyzes the emails and extracts features, such as:\n    *   The presence of certain keywords
# ("free," "money," "urgent").\n    *   The sender\'s email address.\n    *   The frequency of certain words.\n    *
# The structure of the email.\n3.  **Model Training (Machine Learning):**  A machine learning algorithm (e.g., a
# Naive Bayes classifier or a neural network) learns the relationship between these features and the "spam" or "not
# spam" label.  It adjusts its internal parameters to minimize errors.\n4.  **Prediction:**  When a new email
# arrives, the AI extracts the same features and uses the trained model to predict whether it\'s spam or not.\n5.
# **Continuous Learning:**  The spam filter can continue to learn and improve over time as it receives more data and
# feedback (e.g., if a user marks an email as spam that was initially classified as "not spam").\n\n**4. Types of AI
# (Broadly)**\n\nIt\'s helpful to distinguish between these categories:\n\n*   **Narrow or Weak AI:**  AI designed
# for a specific task.  Most AI systems today fall into this category (spam filters, recommendation systems, voice
# assistants). They can be incredibly powerful *within* their specific domain, but they lack general intelligence.\n*
# **General or Strong AI:**  Hypothetical AI that possesses human-level intelligence across a wide range of tasks.
# This type of AI doesn\'t exist yet.\n*   **Super AI:** A hypothetical AI that surpasses human intelligence in every
# aspect. Also doesn\'t exist yet.\n\n**In Summary**\n\nAI works by using algorithms, particularly machine learning
# and deep learning, to analyze data, learn patterns, and make predictions or decisions.  These algorithms are
# trained on vast amounts of data, allowing them to perform tasks that typically require human intelligence. While
# most current AI is "narrow," focused on specific tasks, the field is constantly evolving, with researchers working
# towards more general and powerful forms of AI.\n'
#                     )
#                 ],
#                 role='model'
#             ),
#             citation_metadata=CitationMetadata(
#                 citations=[
#                     Citation(
#                         end_index=4119,
#                         license='',
#                         publication_date=None,
#                         start_index=3971,
#                         title=None,
#                         uri='https://www.prnewswire.com/news-releases/record-breaking-registrants-and-technical-pap
# ers-for-2022-ieeecvf-conference-on-computer-vision-and-pattern-recognition-cvpr-301579890.html'
#                     ),
#                     Citation(
#                         end_index=4165,
#                         license='',
#                         publication_date=None,
#                         start_index=4004,
#                         title=None,
#                         uri='https://www.jmu.edu/cisr/journal/current-issue.shtml'
#                     )
#                 ]
#             ),
#             finish_message=None,
#             token_count=None,
#             avg_logprobs=None,
#             finish_reason=<FinishReason.STOP: 'STOP'>,
#             grounding_metadata=None,
#             index=0,
#             logprobs_result=None,
#             safety_ratings=None
#         )
#     ],
#     model_version='gemini-2.0-pro-exp-02-05',
#     prompt_feedback=None,
#     usage_metadata=GenerateContentResponseUsageMetadata(
#         cached_content_token_count=None,
#         candidates_token_count=1447,
#         prompt_token_count=5,
#         total_token_count=1452
#     ),
#     automatic_function_calling_history=[],
#     parsed=None
# )
