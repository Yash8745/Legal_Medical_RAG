# %%
import pandas as pd 

df=pd.read_csv('../data/raw/paris-2024-faq.csv')

df.head()
# Out:
#             id lang                                              label  \
# 0  50G4-9Wz-fr   fr  Est-il toujours possible de candidater aux Cen...
# 1  6EFUb0FA-fr   fr  Paris 2024 propose-t-il une solution d’héberge...
# 2  FVASOtOh-fr   fr    Qu'est-ce que l'album Panini Équipe de France ?
# 3  IN6et_ZX-fr   fr  Qu'est-ce que la campagne "Rendez-vous avec l'...
# 4  aHSSm1RL-fr   fr            Politique de confidentialité Paris 2024
#
#                                                 body  \
# 0  Désormais, il n’est plus possible de proposer ...
# 1  Paris 2024 n’a pas vocation à proposer de solu...
# 2  Le 2 avril 2024, pour célébrer son 50ᵉ anniver...
# 3  "Rendez-vous avec l'histoire" est la campagne ...
# 4  Version en ligne : 24/06/2024\n\nLe COMITE D'O...
#
#                                          topics  \
# 0    Autres;Terre de Jeux;Programmes Paris 2024
# 1         Autres;Terre de Jeux;TDJ - Volontaire
# 2  Sports et Athlètes;Athlètes;Équipe de France
# ...

# %%
df.describe()
# Out:
#                  id  lang                              label  \
# count          1091  1091                               1091
# unique         1091     2                               1088
# top     50G4-9Wz-fr    en  Combien y a-t-il de volontaires ?
# freq              1   548                                  3
#
#                                                      body  \
# count                                                1091
# unique                                               1087
# top     It is no longer possible to join the Club 2024...
# freq                                                    2
#
#                                    topics  \
# count                                1091
# unique                                162
# top     Ticketing and Hospitality;Tickets
# freq                                   28
#
#                                                       url
# count                                                1091
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1091 entries, 0 to 1090
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      1091 non-null   object
#  1   lang    1091 non-null   object
#  2   label   1091 non-null   object
#  3   body    1091 non-null   object
#  4   topics  1091 non-null   object
#  5   url     1091 non-null   object
# dtypes: object(6)
# memory usage: 51.3+ KB

# %%
df = df[df["lang"] != "fr"]

# %%
df.sample(5)
# Out:
#                id lang                                              label  \
# 918   3KWqh2QF-en   en  What is The schedule for Paris 2024 installati...
# 909   OnlKYpVk-en   en  How is the cleaning of Paris 2024 venues manag...
# 953   y4EeL2Uy-en   en  What are the guidelines for showcasing local h...
# 983   lYRotjrs-en   en  What documents are needed to submit an applica...
# 1035  lkIKpKI6-en   en                           Cookie Notice Paris 2024
#
#                                                    body  \
# 918   The schedule for Paris 2024 installations at t...
# 909   The Paris 2024 venues will be cleaned by speci...
# 953   Highlighting local heritage through video is o...
# 983   In order to apply for a job at Paris 2024, you...
# 1035  The ORGANIZING COMMITTEE FOR THE PARIS 2024 OL...
#
#                                                  topics  \
# 918   Practical informations;Impacts of Games;Ile-de...
# 909    Other;Environmental commitments;Waste management
# ...

# %%
columns=df.columns
columns
# Out:
# Index(['id', 'lang', 'label', 'body', 'topics', 'url'], dtype='object')

# %%
df.drop(columns=["id","lang","url"], inplace=True)

# %%
df.sample(5)
# Out:
#                                                   label  \
# 352     Is it possible to visit the athletes' Villages?
# 394         How can I access the QR code for my ticket?
# 1030  Is a dedicated mobile app planned for the Pari...
# 1029            Where will the competitions take place?
# 905   What measures are being taken to limit the amo...
#
#                                                    body  \
# 352   During the Games, access to the Village will b...
# 394   A secure QR code will appear on your ticket in...
# 1030  A dedicated mobile app designed for the Paris ...
# 1029  The competitions of the Paris 2024 Olympic and...
# 905   The equipment used has been quantified, and wo...
#
#                                                  topics
# 352   Sports and Athletes;Athletes;The athletes' Vil...
# 394                   Ticketing and Hospitality;Tickets
# 1030  Practical informations;Prepare your visit;Gene...
# 1029          Practical informations;Competition venues
# ...

# %%
df.to_json("../data/processed/paris-2024-faq.json", orient="records")
